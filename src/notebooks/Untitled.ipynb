# %%
import seaborn as sns
import pandas as pd
import pickle

# %%
features = '/mnt/raid/C1_ML_Analysis/test_output/contrastive/extract_frames_blind_sweeps_c1_30082022_wscores_train_kmeans_sample_pred_cluster1_simscoreonlyw/epoch=26-val_loss=0.24/extract_frames_blind_sweeps_c1_30082022_wscores_test_kmeansprediction_simscorew16_epoch=125-val_loss=102.47_pred_cluster==1_perplexity_300_sample.pickle'

# %%
df = pd.read_parquet(features.replace('.pickle', '.parquet'))

# %%
sns.scatterplot(df, x='pca_0', y='pca_1', hue='pred_cluster')
# Out:
# <AxesSubplot: xlabel='pca_0', ylabel='pca_1'>
